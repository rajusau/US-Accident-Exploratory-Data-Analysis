# %% [markdown]
# # Exploratory Data Analy Project
# ## US ACCIDENT DATA ANALYSIS
# ### Steps to follow
#
# 1. Select a large real-world dataset from Kaggle.
#
# 2. Perform data preparation & cleaning using Pandas & Numpy.
#
# 3. Perform exploratory analysis & visualization using Matplotlib & Seaborn.
#
# 4. Ask & answer questions about the data in a Jupyter notebook.
#
# 5. Summarize your inferences & write a conclusion.
#
# 6. Document, publish and present and your Jupyter notebook online.

# %% [markdown]
# # TODO
# - information about accidents
# - can use useful to prevent aaccidents

# %% [markdown]
# ### Step1: Select a large real-world dataset from Kaggle.

# %% [markdown]
# ## Here is the link of the data set
# https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents/data

# %% [markdown]
# ### Step 2: Perform data preparation & cleaning using Pandas & Numpy.

# %% [markdown]
# ### Data cleaning and preparation

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# df=pd.read_csv("US_Accidents_March23.csv")

# %%
# Load DataFrame from pickle file
df = pd.read_pickle("C:/DATA SCIENCE ROADMAP/PROJECTS/US Accident Data Analysis (EDA)/datafile.pkl")
# df=pd.read_pickle('datafile.pkl')

# %%
print('The Dataset Contains, Rows: {:,d} & Columns: {}'.format(df.shape[0], df.shape[1]))
# Out:
# The Dataset Contains, Rows: 7,728,394 & Columns: 46

# %%
df.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                 ID   Source  Severity           Start_Time  \
# 0              A-1  Source2         3  2016-02-08 05:46:00
# 1              A-2  Source2         2  2016-02-08 06:07:59
# 2              A-3  Source2         2  2016-02-08 06:49:27
# 3              A-4  Source2         3  2016-02-08 07:23:34
# 4              A-5  Source2         2  2016-02-08 07:39:07
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN
# 1        2016-02-08 06:37:59  39.928059  -82.831184       NaN        NaN
# ...

# %%
df.rename(columns={'Temperature(F)': 'Temperature'}, inplace=True)

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature            float64
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)   Temperature  Wind_Chill(F)   Humidity(%)  Pressure(in)  \
# count  7.728394e+06  7.564541e+06   5.729375e+06  7.554250e+06  7.587715e+06
# mean   5.618423e-01  6.166329e+01   5.825105e+01  6.483104e+01  2.953899e+01
# ...

# %% [markdown]
# #### Finding Missing Values (percentage)

# %%
missing_percentages=df.isna().sum().sort_values(ascending=False)/len(df)
missing_percentages
# Out:
# End_Lat                  4.402935e-01
# End_Lng                  4.402935e-01
# Precipitation(in)        2.851286e-01
# Wind_Chill(F)            2.586590e-01
# Wind_Speed(mph)          7.391355e-02
# Visibility(mi)           2.291524e-02
# Wind_Direction           2.267043e-02
# Humidity(%)              2.253301e-02
# Weather_Condition        2.244438e-02
# Temperature              2.120143e-02
# Pressure(in)             1.820288e-02
# Weather_Timestamp        1.555666e-02
# Nautical_Twilight        3.007869e-03
# Civil_Twilight           3.007869e-03
# Sunrise_Sunset           3.007869e-03
# Astronomical_Twilight    3.007869e-03
# Airport_Code             2.928810e-03
# Street                   1.406372e-03
# Timezone                 1.010300e-03
# Zipcode                  2.477876e-04
# City                     3.273643e-05
# Description              6.469649e-07
# Traffic_Signal           0.000000e+00
# Roundabout               0.000000e+00
# Station                  0.000000e+00
# ...

# %%
type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
missing_percentages[missing_percentages != 0]
# Out:
# End_Lat                  4.402935e-01
# End_Lng                  4.402935e-01
# Precipitation(in)        2.851286e-01
# Wind_Chill(F)            2.586590e-01
# Wind_Speed(mph)          7.391355e-02
# Visibility(mi)           2.291524e-02
# Wind_Direction           2.267043e-02
# Humidity(%)              2.253301e-02
# Weather_Condition        2.244438e-02
# Temperature              2.120143e-02
# Pressure(in)             1.820288e-02
# Weather_Timestamp        1.555666e-02
# Nautical_Twilight        3.007869e-03
# Civil_Twilight           3.007869e-03
# Sunrise_Sunset           3.007869e-03
# Astronomical_Twilight    3.007869e-03
# Airport_Code             2.928810e-03
# Street                   1.406372e-03
# Timezone                 1.010300e-03
# Zipcode                  2.477876e-04
# City                     3.273643e-05
# Description              6.469649e-07
# dtype: float64

# %%
missing_percentages[missing_percentages != 0].plot(kind="barh")
# Out:
# <Axes: >

# %% [markdown]
# remove column which you will not use!! ```optional ```

# %% [markdown]
# ### Step 3: Perform exploratory analysis & visualization using Matplotlib & Seaborn.

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %% [markdown]
# # Columns we will analyze:
# 1. City
# 2. Start time
# 3. Start Lat,Start Lng
# 4. Temparature
# 5. Weather Condition

# %% [markdown]
# ### City

# %%
df.City
# Out:
# 0                Dayton
# 1          Reynoldsburg
# 2          Williamsburg
# 3                Dayton
# 4                Dayton
#                ...
# 7728389       Riverside
# 7728390       San Diego
# 7728391          Orange
# 7728392     Culver City
# 7728393        Highland
# Name: City, Length: 7728394, dtype: object

# %%
cities=df.City.unique()
len(cities)
# Out:
# 13679

# %%
cities_by_accident=df.City.value_counts()
cities_by_accident[:20]
# Out:
# City
# Miami            186917
# Houston          169609
# Los Angeles      156491
# Charlotte        138652
# Dallas           130939
# Orlando          109733
# Austin            97359
# Raleigh           86079
# Nashville         72930
# Baton Rouge       71588
# Atlanta           68186
# Sacramento        66264
# San Diego         55504
# Phoenix           53974
# Minneapolis       51488
# Richmond          48845
# Oklahoma City     46092
# Jacksonville      42447
# Tucson            39304
# Columbia          38178
# Name: count, dtype: int64

# %%
cities_by_accident[:20].plot(kind='barh')
# Out:
# <Axes: ylabel='City'>

# %%
sns.set_style("darkgrid")

# %%
sns.displot(cities_by_accident,kde=True,log_scale=True)

# %%
len(cities_by_accident[cities_by_accident==1])
# Out:
# 1023

# %%
high_accident_cities=cities_by_accident[cities_by_accident >= 2000]
low_accident_cities=cities_by_accident[cities_by_accident < 2000]

# %%
print(len(high_accident_cities)/len(cities))
print(len(low_accident_cities)/len(cities))
# Out:
# 0.04744498866876234
# 0.9524819065721178

# %%
sns.displot(high_accident_cities,kde=True,log_scale=True)

# %%
sns.displot(low_accident_cities,kde=True,log_scale=True)

# %% [markdown]
# ### Start Time

# %%
df.Start_Time
# Out:
# 0          2016-02-08 05:46:00
# 1          2016-02-08 06:07:59
# 2          2016-02-08 06:49:27
# 3          2016-02-08 07:23:34
# 4          2016-02-08 07:39:07
#                   ...
# 7728389    2019-08-23 18:03:25
# 7728390    2019-08-23 19:11:30
# 7728391    2019-08-23 19:00:21
# 7728392    2019-08-23 19:00:21
# 7728393    2019-08-23 18:52:06
# Name: Start_Time, Length: 7728394, dtype: object

# %%
df.Start_Time=pd.to_datetime(df.Start_Time,errors='coerce')

# %%
df.Start_Time[0]
# Out:
# Timestamp('2016-02-08 05:46:00')

# %%
sns.histplot(df.Start_Time.dt.hour,bins=24)
# Out:
# <Axes: xlabel='Start_Time', ylabel='Count'>

# %%
sns.histplot(df.Start_Time.dt.hour,bins=24,stat='percent')
# Out:
# <Axes: xlabel='Start_Time', ylabel='Percent'>

# %% [markdown]
# - ``` A high percentage of accidents occurs during office timing (between 7 am to 9 am and 3 pm to 5 pm) ```

# %%
sns.histplot(df.Start_Time.dt.dayofweek,bins=7,stat='percent')
# Out:
# <Axes: xlabel='Start_Time', ylabel='Percent'>

# %% [markdown]
# - ``` most of the accidents happens in weekdays ```

# %% [markdown]
# <a id="jump-to-cell-34"></a>

# %%
sunday_start_time=df.Start_Time[df.Start_Time.dt.dayofweek == 6]
sns.histplot(sunday_start_time.dt.hour,bins=24,kde=False,stat='percent')
# Out:
# <Axes: xlabel='Start_Time', ylabel='Percent'>

# %% [markdown]
# - ``` On sunday the peak time of accidents is 1 pm to 3 pm ```

# %%
monday_start_time=df.Start_Time[df.Start_Time.dt.dayofweek == 1]
sns.histplot(monday_start_time.dt.hour,bins=24,kde=False,stat='percent')
# Out:
# <Axes: xlabel='Start_Time', ylabel='Percent'>

# %% [markdown]
# - ``` On monday the peak time of accidents is same as original "start time" dataframe which is 7-9 am and 3-5 pm ```

# %%
sns.histplot(df.Start_Time.dt.month,bins=12,kde=False,stat='percent')
# Out:
# <Axes: xlabel='Start_Time', ylabel='Percent'>

# %% [markdown]
# - ``` During winter there is more accidents than summer ```
#
# <a id="jump-to-cell-34"></a>

# %%
df_2019=df[df.Start_Time.dt.year==2019]
sns.histplot(df_2019.Start_Time.dt.month,bins=12,kde=False,stat='percent')
# Out:
# <Axes: xlabel='Start_Time', ylabel='Percent'>

# %%
df.Source
# Out:
# 0          Source2
# 1          Source2
# 2          Source2
# 3          Source2
# 4          Source2
#             ...
# 7728389    Source1
# 7728390    Source1
# 7728391    Source1
# 7728392    Source1
# 7728393    Source1
# Name: Source, Length: 7728394, dtype: object

# %%
df_2019_source1=df_2019[df_2019.Source=='Source1']
sns.histplot(df_2019_source1.Start_Time.dt.month,bins=12,kde=False,stat='percent')
# Out:
# <Axes: xlabel='Start_Time', ylabel='Percent'>

# %%
df_2019_source2=df_2019[df_2019.Source=='Source2']
sns.histplot(df_2019_source2.Start_Time.dt.month,bins=12,kde=False,stat='percent')
# Out:
# <Axes: xlabel='Start_Time', ylabel='Percent'>

# %% [markdown]
# - ` May be a chance that there is some problem with Source1 data `

# %%
df.Source.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Start Lat - Start Lng

# %%
df.Start_Lat
# Out:
# 0          39.865147
# 1          39.928059
# 2          39.063148
# 3          39.747753
# 4          39.627781
#              ...
# 7728389    34.002480
# 7728390    32.766960
# 7728391    33.775450
# 7728392    33.992460
# 7728393    34.133930
# Name: Start_Lat, Length: 7728394, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -84.058723
# 1          -82.831184
# 2          -84.032608
# 3          -84.205582
# 4          -84.188354
#               ...
# 7728389   -117.379360
# 7728390   -117.148060
# 7728391   -117.847790
# 7728392   -118.403020
# 7728393   -117.230920
# Name: Start_Lng, Length: 7728394, dtype: float64

# %%
# sns.scatterplot(x=df.Start_Lng,y=df.Start_Lat)

# %%
zip(list(df.Start_Lat),list(df.Start_Lng))

# %%
import folium
from folium.plugins import HeatMap

# %%
lat,lon=df.Start_Lat[0],df.Start_Lng[0]
lat,lon
# Out:
# (39.865147, -84.058723)

# %%
map=folium.Map()
marker=folium.Marker((lat,lon))
marker.add_to(map)
# map

# %%
sample_df=df.sample(int(0.01 * len(df)))
lat_long=list(zip(list(sample_df.Start_Lat),list(sample_df.Start_Lng)))

# %%
map=folium.Map()
HeatMap(lat_long).add_to(map)
# map

# %% [markdown]
# ### Temparature

# %%
df.Temperature
# Out:
# 0          36.9
# 1          37.9
# 2          36.0
# 3          35.1
# 4          36.0
#            ...
# 7728389    86.0
# 7728390    70.0
# 7728391    73.0
# 7728392    71.0
# 7728393    79.0
# Name: Temperature, Length: 7728394, dtype: float64

# %%
# df.Temperature.mean()
max(df.Temperature)
# Out:
# 207.0

# %%
# sample_df=df.sample(int(0.01 * len(df)))

# %%
sns.displot(df.Temperature,kde=True)

# %% [markdown]
# - ``` From this plot we can say that when there is extreme cold or extreme hot The number of accidents are less than the normal temperature weather ```

# %%
temp=df.Temperature.value_counts()
print(temp)
# Out:
# Temperature
#  77.0     170991
#  73.0     170898
#  68.0     163767
#  72.0     160498
#  75.0     158448
#            ...
#  1.6           1
# -21.5          1
#  127.0         1
#  158.0         1
#  132.6         1
# Name: count, Length: 860, dtype: int64

# %%
temp_values=temp[temp >= 400]
len(temp_values)
# Out:
# 316

# %%
sns.displot(temp_values,kde=True,bins=10)

# %% [markdown]
# - ``` Most of the accidents happens in the normal temperature like 77 to 68 [F] ```

# %%
sns.histplot(x=df.Start_Time.dt.month,y=df.Temperature,bins=12,kde=False,stat='percent')
# Out:
# <Axes: xlabel='Start_Time', ylabel='Temperature'>

# %%
import matplotlib.pyplot as plt


df['Start_Time'] = pd.to_datetime(df['Start_Time'])

df['Month'] = df['Start_Time'].dt.month

df = df.dropna(subset=['Temperature', 'Month'])

plt.figure(figsize=(10, 6))
plt.hist2d(df['Temperature'], df['Month'], bins=(20, 12), cmap=plt.cm.Blues)
plt.colorbar(label='Number of Accidents')
plt.xlabel('Temperature')
plt.ylabel('Month')
plt.title('Number of Accidents by Temperature and Month')
plt.xticks(rotation=45)
plt.yticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df['Start_Time'] = pd.to_datetime(df['Start_Time'])

df['Day_of_Week'] = df['Start_Time'].dt.dayofweek

temperature_ranges = [
    (-50, 0),    # Very Cold
    (0, 32),     # Freezing
    (32, 50),    # Cold
    (50, 68),    # Cool
    (68, 80),    # Warm
    (80, 90),    # Hot
    (90, 100),   # Very Hot
    (100, 150)   # Extremely Hot
]

def categorize_temperature(temp):
    for i, (lower, upper) in enumerate(temperature_ranges):
        if lower <= temp < upper:
            return i
    return len(temperature_ranges) - 1

df['Temperature_Range'] = df['Temperature'].apply(categorize_temperature)

grouped_data = df.groupby(['Day_of_Week', 'Temperature_Range']).size().unstack(fill_value=0)

plt.figure(figsize=(10, 6))
plt.imshow(grouped_data, cmap='Blues', interpolation='nearest', aspect='auto')

plt.colorbar(label='Number of Accidents')

plt.xlabel('Temperature Range')
plt.ylabel('Day of the Week')
plt.xticks(np.arange(len(temperature_ranges)), [f'{temp[0]}-{temp[1]}' for temp in temperature_ranges], rotation=45)
plt.yticks(np.arange(7), ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])

plt.title('Number of Accidents by Day of the Week and Temperature Range')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\thera\AppData\Local\Temp\ipykernel_11844\3622299721.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Start_Time'] = pd.to_datetime(df['Start_Time'])
# C:\Users\thera\AppData\Local\Temp\ipykernel_11844\3622299721.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day_of_Week'] = df['Start_Time'].dt.dayofweek
# C:\Users\thera\AppData\Local\Temp\ipykernel_11844\3622299721.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Convert 'Start_Time' column to datetime format
df['Start_Time'] = pd.to_datetime(df['Start_Time'])

# Create a new column 'Day_Night' to categorize accidents as 'Day' or 'Night'
df['Day_Night'] = pd.cut(df['Start_Time'].dt.hour, bins=[0, 6, 18, 23], labels=['Night', 'Day', 'Night_End'])
# Updated labels to 'Night_End' for hours 18-23

# Create a boxplot to compare temperature for day and night accidents
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Temperature', y='Day_Night', hue='Day_Night', palette='Set2', orient='h', dodge=False)
plt.title('Temperature Patterns for Day and Night Accidents')
plt.xlabel('Temperature (F)')
plt.ylabel('Day/Night')
plt.show()
# Out:
# C:\Users\thera\AppData\Local\Temp\ipykernel_11844\1655094176.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Start_Time'] = pd.to_datetime(df['Start_Time'])
# C:\Users\thera\AppData\Local\Temp\ipykernel_11844\1655094176.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day_Night'] = pd.cut(df['Start_Time'].dt.hour, bins=[0, 6, 18, 23], labels=['Night', 'Day', 'Night_End'])

# %%
df.Sunrise_Sunset
# Out:
# 0          Night
# 1          Night
# 2          Night
# 3          Night
# 4            Day
#            ...
# 7728389      Day
# 7728390      Day
# 7728391      Day
# 7728392      Day
# 7728393      Day
# Name: Sunrise_Sunset, Length: 6839140, dtype: object

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt



# Convert 'Start_Time' column to datetime format
df['Start_Time'] = pd.to_datetime(df['Start_Time'])

# Extract hour of the day
df['Hour'] = df['Start_Time'].dt.hour

# Create a line plot to show temperature fluctuations during sunrise and sunset
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Hour', y='Temperature', hue='Sunrise_Sunset', errorbar=None)
plt.title('Temperature Fluctuations during Sunrise and Sunset')
plt.xlabel('Hour of the Day')
plt.ylabel('Temperature (F)')
plt.xticks(range(0, 24))
plt.legend(title='Sunrise_Sunset')
plt.show()
# Out:
# C:\Users\thera\AppData\Local\Temp\ipykernel_11844\4071040416.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Start_Time'] = pd.to_datetime(df['Start_Time'])
# C:\Users\thera\AppData\Local\Temp\ipykernel_11844\4071040416.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Hour'] = df['Start_Time'].dt.hour

# %% [markdown]
# ### Weather Condition

# %%
import pandas as pd



# Select the columns for correlation analysis
weather_columns = ['Temperature', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)', 
                   'Visibility(mi)', 'Wind_Speed(mph)', 'Precipitation(in)']

# Calculate correlation coefficients with 'Severity'
weather_corr = df[weather_columns + ['Severity']].corr()

# Display correlation matrix
print("Correlation Matrix between Weather Variables and Accident Severity:")
print(weather_corr)
# Out:
# Correlation Matrix between Weather Variables and Accident Severity:
#                    Temperature  Wind_Chill(F)  Humidity(%)  Pressure(in)  \
# Temperature           1.000000       0.993783    -0.329303      0.093735
# Wind_Chill(F)         0.993783       1.000000    -0.311816      0.063928
# Humidity(%)          -0.329303      -0.311816     1.000000      0.119914
# Pressure(in)          0.093735       0.063928     0.119914      1.000000
# Visibility(mi)        0.209012       0.224723    -0.381527      0.029355
# Wind_Speed(mph)       0.032532      -0.047431    -0.172055     -0.019006
# Precipitation(in)    -0.004420      -0.012565     0.074368      0.017999
# Severity             -0.019699      -0.070869     0.019491      0.043970
#
#                    Visibility(mi)  Wind_Speed(mph)  Precipitation(in)  \
# Temperature              0.209012         0.032532          -0.004420
# Wind_Chill(F)            0.224723        -0.047431          -0.012565
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(weather_corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix between Weather Variables and Accident Severity")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Create a countplot of accidents by weather condition
plt.figure(figsize=(12, 8))
sns.countplot(data=df, x='Weather_Condition', hue='Weather_Condition', 
              order=df['Weather_Condition'].value_counts().index[:20], 
              palette='viridis', legend=False)
plt.title('Number of Accidents by Weather Condition')
plt.xlabel('Weather Condition')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# - ``` Most of the accidents happened in the fair weather than the bad weather condtition ```

# %% [markdown]
# ### Step 4: Ask & answer questions about the data in a Jupyter notebook.
#
# 1. Are there more accidents in warmer areas than colder areas?
#
# 2. Which 5 states have the highest number of accidents? How about per capita?
#
# 3. How many numeric column in the data?
#
# 4. Why new york has less numbers of accidents although the population of new york ranks second position?
#
# 5. Among the top 100 cities with highest number of accidents from which states most of them belongs to?
#
# 6. What time of the day and which day of the week most of accidents happens?
#
# 7. Also which month of the year have the most accidents?
#
# 8. what is the trend of accidents over the year (Increasing or decreasing)?
#
# 9. Which City in US has reported most no. of Accident Cases in last 5 years (2016-2020) ?
#
# 10. Which are the top 10 accident prone streets in US ?
#
# 11. Per Day averagely how many road accidents took placed in US ?
#
# 12. In which hours of the day most accidents happened in US ?
#
# 13. How are the basic weather conditions in most of the accident cases in US ?
#
# 14. Which are the top 10 States with most no. of road accident cases in US ?

# %%
# 1 Are there more accidents in warmer areas than colder areas?

cold_cities=['Fairbanks','Grand Forks','Williston','Fargo','Aberdeen']
warm_cities=[ 'Mesa', 'Arizona', 'Honolulu', 'Hawaii', 'Orlando']
city_counts = df['City'].value_counts()

cold = 0
for city in cold_cities:
    cold += city_counts.get(city, 0)

warm=0
for city in warm_cities:
    warm += city_counts.get(city,0)


print(f"Total appearances of cold cities: {cold} & Avg : {cold/5}")
print(f"Total appearances of warm cities:,{warm} & Avg : {warm/5}")
# Out:
# Total appearances of cold cities: 2102 & Avg : 420.4
# Total appearances of warm cities:,98443 & Avg : 19688.6

# %% [markdown]
# - ``` According to the top 5 hottest and coldest cities accident average we Can say that in Warmer cities most of the accidents happens ```

# %%
#2 Which 5 states have the highest number of accidents? How about per capita?

Top5_state=df.State.value_counts()
print("Top 5 states with highest number of accidents:\n",Top5_state[:5])

per_capita=['DC','MA','CT','NJ','CA']
state_counts = df['State'].value_counts()

per_capita_sorted = sorted(per_capita, key=lambda x: state_counts.get(x, 0), reverse=True)

print("Top 5 States with Highest number of accidents from per capita POV:\n",per_capita_sorted)
# Out:
# Top 5 states with highest number of accidents:
#  State
# CA    1526011
# FL     753569
# TX     536753
# SC     344938
# NY     308445
# Name: count, dtype: int64
# Top 5 States with Highest number of accidents from per capita POV:
#  ['CA', 'NJ', 'CT', 'MA', 'DC']

# %%
# 3 How many numeric column in the data?

numeric=['int16','int32','int64','float16','float32','float64']
numeric_df=df.select_dtypes(include=numeric)
len(numeric_df.columns)
# Out:
# 17

# %%
#4  Why new york has less numbers of accidents although the population of new york ranks second position?
# 'New York' in df.City.values
print(f"Total NUmber of accidents in New York is : {df.State.value_counts().get('NY')}. ")
# Out:
# Total NUmber of accidents in New York is : 308445.

# %%
#5 Among the top 100 cities with highest number of accidents from which states most of them belongs to?

top_100_cities = df['City'].value_counts().head(100).index.tolist()
states=df[df.City.isin(top_100_cities)].State.value_counts()
print("Among the top 100 cities with highest number of accidents from states most of them belongs to:",states[:5])
# Out:
# Among the top 100 cities with highest number of accidents from states most of them belongs to: State
# CA    553796
# FL    454296
# TX    441759
# NC    211078
# LA    111829
# Name: count, dtype: int64

# %% [markdown]
# 6. What time of the day and which day of the week most of accidents happens?
# 7. Also which month of the year have the most accidents?
#
# - ``` For the answer of question 6 And 7 go to cell 32 ```
#
#
# [Go to Cell 32](#jump-to-cell-34)

# %%
#8 what is the trend of accidents over the year (Increasing or decreasing)?

sns.histplot(df.Start_Time.dt.year,bins=8,stat='percent')
# Out:
# <Axes: xlabel='Start_Time', ylabel='Percent'>

# %% [markdown]
# - ``` According to The HistPlot Number Of Accidents Are Increasing over The Years ```

# %% [markdown]
# ### Step 5: Summarize your inferences & write a conclusion.

# %% [markdown]
# ### Insights
# 1. less than 5% cities have more than 2000 road accidents per year
# 2. Over 1000 cities has occured only one accidents yearly
# 3. Number of accidents per city decreases exponentially
# 4. A high percentage of accidents occurs during office timing (between 7 am to 9 am and 3 pm to 5 pm)
# 5. Most of the accidents happens in weekdays
# 6. On sunday the peak time of accidents is 1 pm to 3 pm
# 7. On monday the peak time of accidents is same as original "start time" dataframe which is 7-9 am and 3-5 pm
# 8. During winter there is more accidents than summer
# 9. We can say that when there is extreme cold or extreme hot The number of accidents are less than the normal temperature weather
# 10. Most of the accidents happens in the normal temperature like 77 to 68 [F]
# 11. Most of the accidents happened in the fair weather than the bad weather condtition

# %% [markdown]
# ### Step 6: Document, publish and present and your Jupyter notebook online.
